# %%
import pandas as pd
import json

# %%
# Load data
players = pd.read_csv("data/raw_players.csv", parse_dates=["first_seen_at"])
events = pd.read_csv("data/raw_game_events.csv", parse_dates=["event_time"])
sessions = pd.read_csv("data/raw_sessions.csv", parse_dates=["session_start", "session_end"])

# %%
# Find the most recent user (by first_seen_at)
most_recent_player = players.loc[players["first_seen_at"].idxmax()]
most_recent_player_id = most_recent_player["player_id"]

print(f"Most recent player: {most_recent_player_id}")
print(f"First seen at: {most_recent_player['first_seen_at']}")
print(f"Country: {most_recent_player['country']}, Difficulty: {most_recent_player['difficulty_selected']}")
print(f"Number of sessions: {sessions[sessions['player_id'] == most_recent_player_id].shape[0]}")
# Out:
# Most recent player: player_21
# First seen at: 2026-01-28 08:40:46.532138
# Country: FR, Difficulty: normal
# Number of sessions: 1

# %%
most_recent_player.head()
# Out:
# player_id                               player_21
# first_seen_at          2026-01-28 08:40:46.532138
# country                                        FR
# language                                       fr
# difficulty_selected                        normal
# Name: 20, dtype: object

# %%
print("\n" + "="*60)
print("Event Flow:")
print("="*60)

# Get all events for this player, sorted by time
player_events = events[events["player_id"] == most_recent_player_id].sort_values("event_time")

# Parse properties JSON for better display
player_events_display = player_events.copy()
player_events_display["properties"] = player_events_display["properties"].apply(
    lambda x: json.loads(x) if isinstance(x, str) else x
)

# Display event flow
for idx, event in player_events_display.iterrows():
    props_str = ", ".join([f"{k}={v}" for k, v in event["properties"].items()]) if event["properties"] else "{}"
    print(f"{event['event_time']} | {event['event_name']:20s} | {props_str}")

print(f"\nTotal events: {len(player_events)}")
# Out:
# ============================================================
# Event Flow:
# ============================================================
# 2026-01-28 14:40:46.532138 | game_started         | load_time_ms=4064, resolution=4K, fps_target=30, audio_quality=high
# 2026-01-28 14:47:37.532138 | chapter_started      | chapter_id=1, chapter_name=The Outskirts, location=school, weather=fog, time_of_day=dawn
# 2026-01-28 14:47:47.532138 | enemy_killed         | chapter_id=1, enemy_type=infected, enemy_name=runner, weapon_type=rifle, weapon_name=hunting_rifle, damage_dealt=200, headshot=False, distance_meters=6, xp_gained=27, stealth_kill=False
# 2026-01-28 14:54:38.532138 | item_crafted         | chapter_id=1, item_type=molotov, materials_used=['alcohol', 'rag', 'bottle'], crafting_time_seconds=7, success=True, workbench_used=False
# 2026-01-28 14:56:51.532138 | chapter_started      | chapter_id=5, chapter_name=The University, location=park, weather=snow, time_of_day=night
# 2026-01-28 14:57:32.532138 | enemy_killed         | chapter_id=5, enemy_type=infected, enemy_name=stalker, weapon_type=bow, weapon_name=hunting_bow, damage_dealt=209, headshot=True, distance_meters=46, xp_gained=39, stealth_kill=False
# 2026-01-28 14:58:25.532138 | checkpoint_reached   | chapter_id=1, checkpoint_id=3, time_since_chapter_start_seconds=648, health_percentage=77, ammo_count=29, inventory_items=16
# 2026-01-28 14:59:30.532138 | enemy_killed         | chapter_id=5, enemy_type=infected, enemy_name=shambler, weapon_type=bow, weapon_name=hunting_bow, damage_dealt=165, headshot=False, distance_meters=41, xp_gained=39, stealth_kill=True
# 2026-01-28 15:00:02.532138 | chapter_completed    | chapter_id=1, completion_time_seconds=745, score=1300, collectibles_found=4, deaths_count=0, enemies_killed=3, accuracy_percentage=45.3
# 2026-01-28 15:01:38.532138 | chapter_started      | chapter_id=3, chapter_name=Downtown, location=rooftop, weather=fog, time_of_day=night
# 2026-01-28 15:02:13.532138 | enemy_killed         | chapter_id=3, enemy_type=human, enemy_name=bandit, weapon_type=bow, weapon_name=hunting_bow, damage_dealt=113, headshot=False, distance_meters=23, xp_gained=32, stealth_kill=False
# 2026-01-28 15:03:04.532138 | enemy_killed         | chapter_id=3, enemy_type=infected, enemy_name=runner, weapon_type=rifle, weapon_name=hunting_rifle, damage_dealt=178, headshot=True, distance_meters=36, xp_gained=15, stealth_kill=False
# 2026-01-28 15:04:21.532138 | enemy_killed         | chapter_id=3, enemy_type=infected, enemy_name=bloater, weapon_type=pistol, weapon_name=silenced_pistol, damage_dealt=96, headshot=False, distance_meters=15, xp_gained=31, stealth_kill=False
# 2026-01-28 15:04:25.532138 | enemy_killed         | chapter_id=3, enemy_type=human, enemy_name=merchant, weapon_type=bow, weapon_name=compound_bow, damage_dealt=97, headshot=False, distance_meters=17, xp_gained=23, stealth_kill=True
# 2026-01-28 15:04:53.532138 | enemy_killed         | chapter_id=1, enemy_type=human, enemy_name=merchant, weapon_type=rifle, weapon_name=assault_rifle, damage_dealt=60, headshot=False, distance_meters=18, xp_gained=42, stealth_kill=False
# 2026-01-28 15:11:37.532138 | checkpoint_reached   | chapter_id=3, checkpoint_id=1, time_since_chapter_start_seconds=599, health_percentage=40, ammo_count=19, inventory_items=9
# 2026-01-28 15:11:41.532138 | enemy_killed         | chapter_id=5, enemy_type=human, enemy_name=scavenger, weapon_type=bow, weapon_name=hunting_bow, damage_dealt=266, headshot=True, distance_meters=28, xp_gained=50, stealth_kill=True
# 2026-01-28 15:12:44.532138 | checkpoint_reached   | chapter_id=5, checkpoint_id=1, time_since_chapter_start_seconds=953, health_percentage=42, ammo_count=194, inventory_items=15
# 2026-01-28 15:13:44.532138 | checkpoint_reached   | chapter_id=3, checkpoint_id=3, time_since_chapter_start_seconds=726, health_percentage=20, ammo_count=43, inventory_items=9
# 2026-01-28 15:14:37.532138 | checkpoint_reached   | chapter_id=1, checkpoint_id=4, time_since_chapter_start_seconds=1620, health_percentage=50, ammo_count=135, inventory_items=21
# 2026-01-28 15:16:58.532138 | checkpoint_reached   | chapter_id=1, checkpoint_id=2, time_since_chapter_start_seconds=1761, health_percentage=35, ammo_count=4, inventory_items=18
# 2026-01-28 15:18:08.532138 | chapter_started      | chapter_id=2, chapter_name=The Quarantine Zone, location=subway, weather=fog, time_of_day=dusk
# 2026-01-28 15:19:49.532138 | enemy_killed         | chapter_id=3, enemy_type=human, enemy_name=hunter, weapon_type=rifle, weapon_name=sniper_rifle, damage_dealt=164, headshot=True, distance_meters=11, xp_gained=32, stealth_kill=False
# 2026-01-28 15:25:22.532138 | enemy_killed         | chapter_id=5, enemy_type=infected, enemy_name=stalker, weapon_type=bow, weapon_name=hunting_bow, damage_dealt=188, headshot=True, distance_meters=7, xp_gained=22, stealth_kill=False
# 2026-01-28 15:25:34.532138 | checkpoint_reached   | chapter_id=2, checkpoint_id=1, time_since_chapter_start_seconds=446, health_percentage=58, ammo_count=193, inventory_items=10
# 2026-01-28 15:27:27.532138 | player_died          | chapter_id=5, death_reason=environment, health_at_death=28, time_survived_seconds=1836, last_enemy_type=infected, location=warehouse, death_count_in_chapter=1
# 2026-01-28 15:27:37.532138 | item_crafted         | chapter_id=5, item_type=medkit, materials_used=['alcohol', 'rag', 'scissors'], crafting_time_seconds=8, success=True, workbench_used=True
# 2026-01-28 15:28:18.532138 | chapter_completed    | chapter_id=3, completion_time_seconds=1600, score=3905, collectibles_found=3, deaths_count=1, enemies_killed=9, accuracy_percentage=63.7
# 2026-01-28 15:30:17.532138 | chapter_completed    | chapter_id=2, completion_time_seconds=729, score=1160, collectibles_found=4, deaths_count=0, enemies_killed=5, accuracy_percentage=89.9
# 2026-01-28 15:31:57.532138 | enemy_killed         | chapter_id=2, enemy_type=human, enemy_name=scavenger, weapon_type=bow, weapon_name=hunting_bow, damage_dealt=157, headshot=False, distance_meters=45, xp_gained=40, stealth_kill=True
# 2026-01-28 15:35:28.532138 | enemy_killed         | chapter_id=2, enemy_type=infected, enemy_name=bloater, weapon_type=rifle, weapon_name=hunting_rifle, damage_dealt=291, headshot=True, distance_meters=40, xp_gained=48, stealth_kill=False
# 2026-01-28 15:35:34.532138 | chapter_completed    | chapter_id=5, completion_time_seconds=2323, score=818, collectibles_found=2, deaths_count=1, enemies_killed=6, accuracy_percentage=71.2
# 2026-01-28 15:37:49.532138 | enemy_killed         | chapter_id=2, enemy_type=human, enemy_name=merchant, weapon_type=pistol, weapon_name=revolver, damage_dealt=105, headshot=False, distance_meters=26, xp_gained=44, stealth_kill=False
# 2026-01-28 15:39:15.532138 | enemy_killed         | chapter_id=3, enemy_type=infected, enemy_name=runner, weapon_type=pistol, weapon_name=silenced_pistol, damage_dealt=93, headshot=False, distance_meters=43, xp_gained=48, stealth_kill=False
# 2026-01-28 15:39:31.532138 | enemy_killed         | chapter_id=3, enemy_type=human, enemy_name=scavenger, weapon_type=rifle, weapon_name=hunting_rifle, damage_dealt=189, headshot=False, distance_meters=17, xp_gained=41, stealth_kill=False
# 2026-01-28 15:41:00.532138 | checkpoint_reached   | chapter_id=3, checkpoint_id=2, time_since_chapter_start_seconds=2362, health_percentage=87, ammo_count=108, inventory_items=13
# 2026-01-28 15:43:29.532138 | chapter_started      | chapter_id=4, chapter_name=The Suburbs, location=park, weather=clear, time_of_day=dawn
# 2026-01-28 15:43:47.532138 | enemy_killed         | chapter_id=4, enemy_type=human, enemy_name=merchant, weapon_type=pistol, weapon_name=revolver, damage_dealt=80, headshot=False, distance_meters=20, xp_gained=46, stealth_kill=True
# 2026-01-28 15:43:52.532138 | checkpoint_reached   | chapter_id=4, checkpoint_id=2, time_since_chapter_start_seconds=23, health_percentage=51, ammo_count=149, inventory_items=10
# 2026-01-28 15:46:20.532138 | checkpoint_reached   | chapter_id=4, checkpoint_id=3, time_since_chapter_start_seconds=171, health_percentage=39, ammo_count=38, inventory_items=18
# 2026-01-28 15:47:36.532138 | enemy_killed         | chapter_id=5, enemy_type=human, enemy_name=soldier, weapon_type=rifle, weapon_name=assault_rifle, damage_dealt=94, headshot=False, distance_meters=15, xp_gained=17, stealth_kill=False
# 2026-01-28 15:48:52.532138 | enemy_killed         | chapter_id=4, enemy_type=infected, enemy_name=shambler, weapon_type=pistol, weapon_name=revolver, damage_dealt=166, headshot=False, distance_meters=46, xp_gained=16, stealth_kill=False
# 2026-01-28 15:49:20.532138 | player_died          | chapter_id=3, death_reason=explosion, health_at_death=20, time_survived_seconds=2862, last_enemy_type=infected, location=apartment, death_count_in_chapter=1
# 2026-01-28 15:51:59.532138 | enemy_killed         | chapter_id=3, enemy_type=human, enemy_name=merchant, weapon_type=rifle, weapon_name=assault_rifle, damage_dealt=182, headshot=False, distance_meters=28, xp_gained=40, stealth_kill=False
# 2026-01-28 15:53:37.532138 | enemy_killed         | chapter_id=5, enemy_type=infected, enemy_name=clicker, weapon_type=pistol, weapon_name=9mm_pistol, damage_dealt=148, headshot=False, distance_meters=50, xp_gained=18, stealth_kill=True
# 2026-01-28 15:54:05.532138 | enemy_killed         | chapter_id=4, enemy_type=human, enemy_name=scavenger, weapon_type=pistol, weapon_name=revolver, damage_dealt=202, headshot=True, distance_meters=28, xp_gained=43, stealth_kill=False
# 2026-01-28 15:54:16.532138 | checkpoint_reached   | chapter_id=5, checkpoint_id=2, time_since_chapter_start_seconds=3445, health_percentage=47, ammo_count=142, inventory_items=11
# 2026-01-28 15:55:49.532138 | player_died          | chapter_id=4, death_reason=combat, health_at_death=1, time_survived_seconds=740, last_enemy_type=infected, location=park, death_count_in_chapter=1
# 2026-01-28 15:55:56.532138 | enemy_killed         | chapter_id=3, enemy_type=infected, enemy_name=clicker, weapon_type=rifle, weapon_name=assault_rifle, damage_dealt=216, headshot=True, distance_meters=25, xp_gained=20, stealth_kill=False
# 2026-01-28 15:56:01.532138 | checkpoint_reached   | chapter_id=4, checkpoint_id=1, time_since_chapter_start_seconds=752, health_percentage=58, ammo_count=181, inventory_items=12
# 2026-01-28 15:57:36.532138 | enemy_killed         | chapter_id=1, enemy_type=human, enemy_name=scavenger, weapon_type=rifle, weapon_name=assault_rifle, damage_dealt=197, headshot=True, distance_meters=9, xp_gained=39, stealth_kill=False
# 2026-01-28 15:59:14.532138 | enemy_killed         | chapter_id=2, enemy_type=infected, enemy_name=shambler, weapon_type=bow, weapon_name=hunting_bow, damage_dealt=172, headshot=False, distance_meters=23, xp_gained=32, stealth_kill=True
# 2026-01-28 15:59:46.532138 | enemy_killed         | chapter_id=4, enemy_type=infected, enemy_name=stalker, weapon_type=rifle, weapon_name=hunting_rifle, damage_dealt=290, headshot=True, distance_meters=32, xp_gained=47, stealth_kill=False
# 2026-01-28 16:00:12.532138 | checkpoint_reached   | chapter_id=1, checkpoint_id=1, time_since_chapter_start_seconds=4355, health_percentage=73, ammo_count=97, inventory_items=9
# 2026-01-28 16:00:30.532138 | enemy_killed         | chapter_id=2, enemy_type=infected, enemy_name=clicker, weapon_type=pistol, weapon_name=9mm_pistol, damage_dealt=70, headshot=False, distance_meters=46, xp_gained=31, stealth_kill=True
# 2026-01-28 16:01:50.532138 | chapter_completed    | chapter_id=4, completion_time_seconds=1101, score=3460, collectibles_found=3, deaths_count=1, enemies_killed=6, accuracy_percentage=56.6
# 2026-01-28 16:04:22.532138 | enemy_killed         | chapter_id=4, enemy_type=human, enemy_name=merchant, weapon_type=bow, weapon_name=hunting_bow, damage_dealt=208, headshot=True, distance_meters=26, xp_gained=20, stealth_kill=False
# 2026-01-28 16:04:40.532138 | enemy_killed         | chapter_id=4, enemy_type=human, enemy_name=soldier, weapon_type=rifle, weapon_name=assault_rifle, damage_dealt=82, headshot=False, distance_meters=34, xp_gained=11, stealth_kill=True
# 2026-01-28 16:04:46.532138 | game_closed          | session_duration_seconds=5040, reason=idle_timeout, total_deaths=3, total_enemies_killed=29, chapters_completed=5, achievements_unlocked=0, final_score=2535
#
# Total events: 59
